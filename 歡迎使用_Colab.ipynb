# %% [markdown]
# <a href="https://colab.research.google.com/github/yij79760-dev/115-1/blob/main/%E6%AD%A1%E8%BF%8E%E4%BD%BF%E7%94%A8_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 新增區段

# %%
x=int(input("清輸入目前金幣數量:"))
y=int(input("請輸入獲得金幣數量:"))
z=x+y
print(f"任務完成! 你現在有{z}枚金幣")
# Out:
# 清輸入目前金幣數量:500
# 請輸入獲得金幣數量:250
# 任務完成! 你現在有750枚金幣
