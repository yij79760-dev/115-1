# %% [markdown]
# <a href="https://colab.research.google.com/github/yij79760-dev/115-1/blob/main/411414931_H1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 新增區段

# %%
X=50000*(1+0.015)**5
print(X)
# Out:
# 53864.20019421873
